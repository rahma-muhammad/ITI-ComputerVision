# %%
import tensorflow as tf

# %%
import numpy as np
import time

# %%
print(tf.version.VERSION)
print(tf.__version__)
# Out:
# 2.9.1
# 2.9.1

# %%
c = np.array([-40, -10, 0, 8, 15, 22, 38], dtype=float)
f = np.array([-40, 14, 32, 46, 59, 72, 100], dtype =float)

# %%
c.shape
# Out:
# (7,)

# %%
model = tf.keras.Sequential(
    tf.keras.layers.Dense(units=1, input_shape=[1])
)

# %%
model.compile(
    loss='mean_squared_error',
    optimizer=tf.keras.optimizers.Adam(0.1)
)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 1)                 2
#
# ...
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________

# %%
tf.kera.utils.plot_model(
    

)

# %%
hist = model.fit(c, f, epochs=800)
# Out:
# Epoch 1/800
# 1/1 [==============================] - 0s 377ms/step - loss: 4523.6694
# Epoch 2/800
# 1/1 [==============================] - 0s 9ms/step - loss: 4239.2461
# Epoch 3/800
# 1/1 [==============================] - 0s 11ms/step - loss: 3966.5562
# Epoch 4/800
# 1/1 [==============================] - 0s 6ms/step - loss: 3705.7864
# Epoch 5/800
# 1/1 [==============================] - 0s 10ms/step - loss: 3457.1001
# Epoch 6/800
# 1/1 [==============================] - 0s 6ms/step - loss: 3220.6257
# Epoch 7/800
# 1/1 [==============================] - 0s 9ms/step - loss: 2996.4592
# Epoch 8/800
# 1/1 [==============================] - 0s 11ms/step - loss: 2784.6614
# Epoch 9/800
# 1/1 [==============================] - 0s 9ms/step - loss: 2585.2524
# Epoch 10/800
# 1/1 [==============================] - 0s 11ms/step - loss: 2398.2134
# Epoch 11/800
# 1/1 [==============================] - 0s 15ms/step - loss: 2223.4795
# Epoch 12/800
# ...

# %%
len(hist.history['loss'])
# Out:
# 800

# %%
import matplotlib.pyplot as plt

# %%
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.plot(hist.history['loss']);

# %%
model.get_weights()
# Out:
# [array([[1.7997898]], dtype=float32), array([31.73571], dtype=float32)]

# %%
model.predict(np.array([60]))
# Out:
# 1/1 [==============================] - 0s 120ms/step
# array([[139.7231]], dtype=float32)

# %%
model.predict(np.array([80]))
# Out:
# 1/1 [==============================] - 0s 40ms/step
# array([[175.7189]], dtype=float32)

# %%
# !conda install --yes freetype=2.10.4
# Out:
# ...
# Solving environment: ...working... done
#
# # All requested packages already installed.
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/msys2/noarch/current_repodata.json HTTP/1.1" 304 0
# DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/main/noarch/current_repodata.json HTTP/1.1" 304 0
# DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/main/win-64/current_repodata.json HTTP/1.1" 200 None
# ...
